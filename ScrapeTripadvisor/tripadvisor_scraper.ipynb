# %%
#!/usr/bin/env python

#import sys
#!{sys.executable} -m pip install easydict #explain: auto install package firstTime

from datetime import datetime
from time import time
from lxml import html,etree
import requests,re
import os,sys
import unicodecsv as csv
import argparse
from easydict import EasyDict as edict

def parse(locality,checkin_date,checkout_date,sort):
    checkIn = checkin_date.strftime("%Y/%m/%d")
    checkOut = checkout_date.strftime("%Y/%m/%d")
    print ("Scraper Inititated for Locality:%s"%locality)
    # TA rendering the autocomplete list using this API
    print ("Finding search result page URL")
    geo_url = 'https://www.tripadvisor.com/TypeAheadJson?action=API&startTime='+str(int(time()))+'&uiOrigin=GEOSCOPE&source=GEOSCOPE&interleaved=true&types=geo,theme_park&neighborhood_geos=true&link_type=hotel&details=true&max=12&injectNeighborhoods=true&query='+locality
    api_response  = requests.get(geo_url, verify=False).json()
    #getting the TA url for th equery from the autocomplete response
    url_from_autocomplete = "http://www.tripadvisor.com"+api_response['results'][0]['url']
    print ('URL found %s'%url_from_autocomplete)
    geo = api_response['results'][0]['value']   
    #Formating date for writing to file 
    
    date = checkin_date.strftime("%Y_%m_%d")+"_"+checkout_date.strftime("%Y_%m_%d")
    #form data to get the hotels list from TA for the selected date
    form_data = {'changeSet': 'TRAVEL_INFO',
            'showSnippets': 'false',
            'staydates':date,
            'uguests': '2',
            'sortOrder':sort
    }
    #Referrer is necessary to get the correct response from TA if not provided they will redirect to home page
    headers = {
                            'Accept': 'text/javascript, text/html, application/xml, text/xml, */*',
                            'Accept-Encoding': 'gzip,deflate',
                            'Accept-Language': 'en-US,en;q=0.5',
                            'Cache-Control': 'no-cache',
                            'Connection': 'keep-alive',
                            'Content-Type': 'application/x-www-form-urlencoded; charset=utf-8',
                            'Host': 'www.tripadvisor.com',
                            'Pragma': 'no-cache',
                            'Referer': url_from_autocomplete,
                            'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux i686; rv:28.0) Gecko/20100101 Firefox/28.0',
                            'X-Requested-With': 'XMLHttpRequest'
                        }
    cookies=  {"SetCurrency":"USD"}
    print ("Downloading search results page")
    page_response  = requests.post(url = url_from_autocomplete,data=form_data,headers = headers, cookies = cookies, verify=False)
    print ("Parsing results ")
    parser = html.fromstring(page_response.text)
    hotel_lists = parser.xpath('//div[contains(@class,"listItem")]//div[contains(@class,"listing collapsed")]')
    hotel_data = []
    if not hotel_lists:
        hotel_lists = parser.xpath('//div[contains(@class,"listItem")]//div[@class="listing "]')

    for hotel in hotel_lists:
        XPATH_HOTEL_LINK = './/a[contains(@class,"property_title")]/@href'
        XPATH_REVIEWS  = './/a[@class="review_count"]//text()'
        XPATH_RANK = './/div[@class="popRanking"]//text()'
        XPATH_RATING = './/span[contains(@class,"rating")]/@alt'
        XPATH_HOTEL_NAME = './/a[contains(@class,"property_title")]//text()'
        XPATH_HOTEL_FEATURES = './/div[contains(@class,"common_hotel_icons_list")]//li//text()'
        XPATH_HOTEL_PRICE = './/div[contains(@data-sizegroup,"mini-meta-price")]/text()'
        XPATH_VIEW_DEALS = './/div[contains(@data-ajax-preserve,"viewDeals")]//text()' 
        XPATH_BOOKING_PROVIDER = './/div[contains(@data-sizegroup,"mini-meta-provider")]//text()'

        raw_booking_provider = hotel.xpath(XPATH_BOOKING_PROVIDER)
        raw_no_of_deals =  hotel.xpath(XPATH_VIEW_DEALS)
        raw_hotel_link = hotel.xpath(XPATH_HOTEL_LINK)
        raw_no_of_reviews = hotel.xpath(XPATH_REVIEWS)
        raw_rank = hotel.xpath(XPATH_RANK)
        raw_rating = hotel.xpath(XPATH_RATING)
        raw_hotel_name = hotel.xpath(XPATH_HOTEL_NAME)
        raw_hotel_features = hotel.xpath(XPATH_HOTEL_FEATURES)
        raw_hotel_price_per_night  = hotel.xpath(XPATH_HOTEL_PRICE)

        url = 'http://www.tripadvisor.com'+raw_hotel_link[0] if raw_hotel_link else  None
        reviews = ''.join(raw_no_of_reviews).replace("reviews","").replace(",","") if raw_no_of_reviews else 0 
        rank = ''.join(raw_rank) if raw_rank else None
        rating = ''.join(raw_rating).replace('of 5 bubbles','').strip() if raw_rating else None
        name = ''.join(raw_hotel_name).strip() if raw_hotel_name else None
        hotel_features = ','.join(raw_hotel_features)
        price_per_night = ''.join(raw_hotel_price_per_night).replace('\n','') if raw_hotel_price_per_night else None
        no_of_deals = re.findall("all\s+?(\d+)\s+?",''.join(raw_no_of_deals))
        booking_provider = ''.join(raw_booking_provider).strip() if raw_booking_provider else None

        if no_of_deals:
            no_of_deals = no_of_deals[0]
        else:
            no_of_deals = 0
            
        data = {
                    'hotel_name':name,
                    'url':url,
                    'locality':locality,
                    'reviews':reviews,
                    'tripadvisor_rating':rating,
                    'checkOut':checkOut,
                    'checkIn':checkIn,
                    'hotel_features':hotel_features,
                    'price_per_night':price_per_night,
                    'no_of_deals':no_of_deals,
                    'booking_provider':booking_provider

        }
        hotel_data.append(data)
    return hotel_data

if __name__ == '__main__':
#     parser = argparse.ArgumentParser()
#     parser.add_argument('checkin_date',help = 'Hotel Check In Date (Format: YYYY/MM/DD')
#     parser.add_argument('checkout_date',help = 'Hotel Chek Out Date (Format: YYYY/MM/DD)')
#     sortorder_help = """
#     available sort orders are :\n
#     priceLow - hotels with lowest price,
#     distLow : Hotels located near to the search center,
#     recommended: highest rated hotels based on traveler reviews,
#     popularity :Most popular hotels as chosen by Tipadvisor users 
#     """
#     parser.add_argument('sort',help = sortorder_help,default ='popularity ')
#     parser.add_argument('locality',help = 'Search Locality')
#     args = parser.parse_args(argv[1:])
    args = edict({
    'checkin_date': '2018/10/09',
    'checkout_date': '2018/10/10',
        'sort':'popularity',
      'locality'  :'boston'
    }) #explain: ALT way type input by static input\n",
    locality = args.locality
    checkin_date = datetime.strptime(args.checkin_date,"%Y/%m/%d")
    checkout_date = datetime.strptime(args.checkout_date,"%Y/%m/%d")
    sort= args.sort
    checkIn = checkin_date.strftime("%Y/%m/%d")
    checkOut = checkout_date.strftime("%Y/%m/%d")
    today = datetime.now()
   
    if today<datetime.strptime(checkIn,"%Y/%m/%d") and datetime.strptime(checkIn,"%Y/%m/%d")<datetime.strptime(checkOut,"%Y/%m/%d"):
        data = parse(locality,checkin_date,checkout_date,sort)
        print (data)
        print ("Writing to output file tripadvisor_SCRAPED.csv")
        with open('tripadvisor_SCRAPED.csv','wb')as csvfile:
            fieldnames = ['hotel_name','url','locality','reviews','tripadvisor_rating','checkIn','checkOut','price_per_night','booking_provider','no_of_deals','hotel_features']
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()
            for row in  data:
                print(row)
                writer.writerow(row)
#     checking whether the entered date is already passed
    elif today>datetime.strptime(checkIn,"%Y/%m/%d") or today>datetime.strptime(checkOut,"%Y/%m/%d"):
        print ("Invalid Checkin date: Please enter a valid checkin and checkout dates,entered date is already passed")
    
    elif datetime.strptime(checkIn,"%Y/%m/%d")>datetime.strptime(checkOut,"%Y/%m/%d"):
        print ("Invalid Checkin date: CheckIn date must be less than checkOut date")
# Out:
# Scraper Inititated for Locality:boston
# Finding search result page URL
# /Users/duongtuan/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# URL found http://www.tripadvisor.com/Hotels-g60745-Boston_Massachusetts-Hotels.html
# Downloading search results page
# /Users/duongtuan/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# Parsing results
# [{'hotel_name': 'The Godfrey Hotel Boston', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d8316858-Reviews-The_Godfrey_Hotel_Boston-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '4412 ', 'tripadvisor_rating': '4.5', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Room Service,Hotel website', 'price_per_night': '$729', 'no_of_deals': '6', 'booking_provider': 'Hotels.com'}, {'hotel_name': 'Omni Parker House', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d89599-Reviews-Omni_Parker_House-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '8825 ', 'tripadvisor_rating': '4', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Restaurant,Room Service,Hotel website', 'price_per_night': '$849', 'no_of_deals': '6', 'booking_provider': 'Agoda.com'}, {'hotel_name': 'The Godfrey Hotel Boston', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d8316858-Reviews-The_Godfrey_Hotel_Boston-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '4412 ', 'tripadvisor_rating': '4.5', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Room Service,Hotel website', 'price_per_night': '$729', 'no_of_deals': '6', 'booking_provider': 'Hotels.com'}, {'hotel_name': 'Hyatt Regency Boston Harbor', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d89620-Reviews-Hyatt_Regency_Boston_Harbor-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '2912 ', 'tripadvisor_rating': '4', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Restaurant', 'price_per_night': '$539', 'no_of_deals': '5', 'booking_provider': 'Hyatt.com'}, {'hotel_name': 'Taj Boston', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d89615-Reviews-Taj_Boston-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '3153 ', 'tripadvisor_rating': '4', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Restaurant,Hotel website', 'price_per_night': '$773', 'no_of_deals': 0, 'booking_provider': 'Hotels.com'}, {'hotel_name': 'Lenox Hotel', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d114134-Reviews-Lenox_Hotel-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '3619 ', 'tripadvisor_rating': '4.5', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Restaurant', 'price_per_night': '$625', 'no_of_deals': '5', 'booking_provider': 'Agoda.com'}, {'hotel_name': 'The Godfrey Hotel Boston', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d8316858-Reviews-The_Godfrey_Hotel_Boston-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '4412 ', 'tripadvisor_rating': '4.5', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Room Service,Hotel website', 'price_per_night': '$729', 'no_of_deals': '6', 'booking_provider': 'Hotels.com'}, {'hotel_name': 'Courtyard Boston Downtown/North Station', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d13403186-Reviews-Courtyard_Boston_Downtown_North_Station-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '139 ', 'tripadvisor_rating': '5', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Restaurant,Hotel website', 'price_per_night': '$819', 'no_of_deals': 0, 'booking_provider': 'TripAdvisor'}, {'hotel_name': 'Bricco Suites', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d3952875-Reviews-Bricco_Suites-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '245 ', 'tripadvisor_rating': '4', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Restaurant', 'price_per_night': '$490', 'no_of_deals': 0, 'booking_provider': 'Agoda.com'}, {'hotel_name': 'Charlesmark Hotel', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d225873-Reviews-Charlesmark_Hotel-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '997 ', 'tripadvisor_rating': '4', 'checkOut': '2018/10/10', 'checkIn': '20 ...
# Writing to output file tripadvisor_SCRAPED.csv
# {'hotel_name': 'The Godfrey Hotel Boston', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d8316858-Reviews-The_Godfrey_Hotel_Boston-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '4412 ', 'tripadvisor_rating': '4.5', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Room Service,Hotel website', 'price_per_night': '$729', 'no_of_deals': '6', 'booking_provider': 'Hotels.com'}
# {'hotel_name': 'Omni Parker House', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d89599-Reviews-Omni_Parker_House-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '8825 ', 'tripadvisor_rating': '4', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Restaurant,Room Service,Hotel website', 'price_per_night': '$849', 'no_of_deals': '6', 'booking_provider': 'Agoda.com'}
# {'hotel_name': 'The Godfrey Hotel Boston', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d8316858-Reviews-The_Godfrey_Hotel_Boston-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '4412 ', 'tripadvisor_rating': '4.5', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Room Service,Hotel website', 'price_per_night': '$729', 'no_of_deals': '6', 'booking_provider': 'Hotels.com'}
# {'hotel_name': 'Hyatt Regency Boston Harbor', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d89620-Reviews-Hyatt_Regency_Boston_Harbor-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '2912 ', 'tripadvisor_rating': '4', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Restaurant', 'price_per_night': '$539', 'no_of_deals': '5', 'booking_provider': 'Hyatt.com'}
# {'hotel_name': 'Taj Boston', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d89615-Reviews-Taj_Boston-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '3153 ', 'tripadvisor_rating': '4', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Restaurant,Hotel website', 'price_per_night': '$773', 'no_of_deals': 0, 'booking_provider': 'Hotels.com'}
# {'hotel_name': 'Lenox Hotel', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d114134-Reviews-Lenox_Hotel-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '3619 ', 'tripadvisor_rating': '4.5', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Restaurant', 'price_per_night': '$625', 'no_of_deals': '5', 'booking_provider': 'Agoda.com'}
# {'hotel_name': 'The Godfrey Hotel Boston', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d8316858-Reviews-The_Godfrey_Hotel_Boston-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '4412 ', 'tripadvisor_rating': '4.5', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Room Service,Hotel website', 'price_per_night': '$729', 'no_of_deals': '6', 'booking_provider': 'Hotels.com'}
# {'hotel_name': 'Courtyard Boston Downtown/North Station', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d13403186-Reviews-Courtyard_Boston_Downtown_North_Station-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '139 ', 'tripadvisor_rating': '5', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Restaurant,Hotel website', 'price_per_night': '$819', 'no_of_deals': 0, 'booking_provider': 'TripAdvisor'}
# {'hotel_name': 'Bricco Suites', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d3952875-Reviews-Bricco_Suites-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '245 ', 'tripadvisor_rating': '4', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Restaurant', 'price_per_night': '$490', 'no_of_deals': 0, 'booking_provider': 'Agoda.com'}
# {'hotel_name': 'Charlesmark Hotel', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d225873-Reviews-Charlesmark_Hotel-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '997 ', 'tripadvisor_rating': '4', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Breakfast included', 'price_per_night': '$399', 'no_of_deals': 0, 'booking_provider': 'Booking.com'}
# {'hotel_name': 'Boston Park Plaza', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d111418-Reviews-Boston_Park_Plaza-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '3132 ', 'tripadvisor_rating': '4', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Restaurant,Room Service,Hotel website', 'price_per_night': '$569', 'no_of_deals': '6', 'booking_provider': 'HotelQuickly'}
# {'hotel_name': 'Sheraton Boston Hotel', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d89602-Reviews-Sheraton_Boston_Hotel-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '2855 ', 'tripadvisor_rating': '4', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Pool,Restaurant,Hotel website', 'price_per_night': '$669', 'no_of_deals': '5', 'booking_provider': 'Sheraton.com'}
# {'hotel_name': 'The Midtown Hotel', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d94350-Reviews-The_Midtown_Hotel-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '4111 ', 'tripadvisor_rating': '3.5', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Pool', 'price_per_night': '$359', 'no_of_deals': '5', 'booking_provider': 'Hotels.com'}
# {'hotel_name': 'Holiday Inn Express Boston', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d121009-Reviews-Holiday_Inn_Express_Boston-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '881 ', 'tripadvisor_rating': '4', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Free Parking,Hotel website', 'price_per_night': '$469', 'no_of_deals': '7', 'booking_provider': 'Agoda.com'}
# {'hotel_name': 'DoubleTree by Hilton Hotel Boston Bayside', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d94368-Reviews-DoubleTree_by_Hilton_Hotel_Boston_Bayside-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '1930 ', 'tripadvisor_rating': '4', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Restaurant,Bar/Lounge,Hotel website', 'price_per_night': '$458', 'no_of_deals': '5', 'booking_provider': 'AMOMA'}
# {'hotel_name': 'Ramada by Wyndham Boston', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d217148-Reviews-Ramada_by_Wyndham_Boston-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '652 ', 'tripadvisor_rating': '3', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Free Parking,Hotel website', 'price_per_night': '$255', 'no_of_deals': '7', 'booking_provider': 'HotelQuickly'}
# {'hotel_name': 'Embassy Suites by Hilton Boston at Logan Airport', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d268205-Reviews-Embassy_Suites_by_Hilton_Boston_at_Logan_Airport-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '2605 ', 'tripadvisor_rating': '4', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Breakfast included,Pool,Hotel website', 'price_per_night': '$594', 'no_of_deals': '6', 'booking_provider': 'Hotels.com'}
# {'hotel_name': 'Hotel Boston', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d77629-Reviews-Hotel_Boston-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '592 ', 'tripadvisor_rating': '3.5', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Breakfast included', 'price_per_night': '$261', 'no_of_deals': '5', 'booking_provider': 'Agoda.com'}
# {'hotel_name': 'Studio Allston Hotel', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d217000-Reviews-Studio_Allston_Hotel-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '62 ', 'tripadvisor_rating': '4', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Restaurant,Hotel website', 'price_per_night': '$320', 'no_of_deals': 0, 'booking_provider': 'Agoda.com'}
# {'hotel_name': 'AC Hotel by Marriott Boston Downtown', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d12882338-Reviews-AC_Hotel_by_Marriott_Boston_Downtown-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '106 ', 'tripadvisor_rating': '4.5', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Restaurant,Hotel website', 'price_per_night': '$689', 'no_of_deals': 0, 'booking_provider': 'Hotels.com'}
# {'hotel_name': 'Hilton Boston Back Bay', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d111428-Reviews-Hilton_Boston_Back_Bay-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '3188 ', 'tripadvisor_rating': '4', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Pool,Hotel website', 'price_per_night': '$629', 'no_of_deals': '6', 'booking_provider': 'Agoda.com'}
# {'hotel_name': 'AC Hotel by Marriott Boston Cleveland Circle', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d13351021-Reviews-AC_Hotel_by_Marriott_Boston_Cleveland_Circle-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '35 ', 'tripadvisor_rating': '4', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Bar/Lounge,Hotel website', 'price_per_night': '$459', 'no_of_deals': 0, 'booking_provider': 'Agoda.com'}
# {'hotel_name': 'Holiday Inn Express Hotel & Suites Boston Garden', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d1138709-Reviews-Holiday_Inn_Express_Hotel_Suites_Boston_Garden-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '585 ', 'tripadvisor_rating': '3.5', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Breakfast included,Hotel website', 'price_per_night': '$819', 'no_of_deals': '6', 'booking_provider': 'HotelQuickly'}
# {'hotel_name': 'Courtyard Boston-South Boston', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d555224-Reviews-Courtyard_Boston_South_Boston-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '578 ', 'tripadvisor_rating': '4', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Free Parking,Hotel website', 'price_per_night': '$899', 'no_of_deals': '5', 'booking_provider': 'Hotels.com'}
# {'hotel_name': 'W Boston', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d1486034-Reviews-W_Boston-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '1933 ', 'tripadvisor_rating': '4.5', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Restaurant,Room Service,Hotel website', 'price_per_night': '$2,399', 'no_of_deals': '6', 'booking_provider': 'Agoda.com'}
# {'hotel_name': 'The Ritz-Carlton, Boston', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d222955-Reviews-The_Ritz_Carlton_Boston-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '923 ', 'tripadvisor_rating': '4.5', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Restaurant,Room Service,Hotel website', 'price_per_night': '$1,995', 'no_of_deals': '5', 'booking_provider': 'Hotels.com'}
# {'hotel_name': 'Hotel Commonwealth', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d258705-Reviews-Hotel_Commonwealth-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '4731 ', 'tripadvisor_rating': '4.5', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Restaurant,Hotel website', 'price_per_night': None, 'no_of_deals': '5', 'booking_provider': 'Agoda.com'}
# {'hotel_name': 'Residence Inn by Marriott Boston Harbor on Tudor Wharf', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d268207-Reviews-Residence_Inn_by_Marriott_Boston_Harbor_on_Tudor_Wharf-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '946 ', 'tripadvisor_rating': '4.5', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Breakfast included,Hotel website', 'price_per_night': None, 'no_of_deals': '5', 'booking_provider': 'Hotels.com'}
# {'hotel_name': 'Harborside Inn', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d94367-Reviews-Harborside_Inn-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '1605 ', 'tripadvisor_rating': '4', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi', 'price_per_night': None, 'no_of_deals': 0, 'booking_provider': 'TripAdvisor'}
# {'hotel_name': 'Bostonian Boston', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d114150-Reviews-Bostonian_Boston-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '1993 ', 'tripadvisor_rating': '4.5', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Restaurant', 'price_per_night': None, 'no_of_deals': '5', 'booking_provider': 'Agoda.com'}
# {'hotel_name': 'Hyatt Regency Boston', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d111441-Reviews-Hyatt_Regency_Boston-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '4416 ', 'tripadvisor_rating': '4', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Free Wifi,Pool,Hotel website', 'price_per_night': None, 'no_of_deals': '6', 'booking_provider': 'TripAdvisor'}
# {'hotel_name': 'Fairmont Copley Plaza, Boston', 'url': 'http://www.tripadvisor.com/Hotel_Review-g60745-d111444-Reviews-Fairmont_Copley_Plaza_Boston-Boston_Massachusetts.html', 'locality': 'boston', 'reviews': '3622 ', 'tripadvisor_rating': '4.5', 'checkOut': '2018/10/10', 'checkIn': '2018/10/09', 'hotel_features': 'Restaurant,Room Service,Hotel website', 'price_per_night': None, 'no_of_deals': '5', 'booking_provider': 'Agoda.com'}
